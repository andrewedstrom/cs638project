# %%
#load csv dataframe
import pandas as pd
import py_entitymatching as em
import math
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style
import re

# Read in original tables
rl = em.read_csv_metadata("../finalRedlist.csv", encoding="ISO-8859-1", key='id')
ar = em.read_csv_metadata("../finalArkives.csv", encoding="ISO-8859-1", key='id')

G = em.read_csv_metadata("to_label.csv", ltable=rl, rtable=ar, encoding="ISO-8859-1")
G1 = G[:200]
G1
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.
#          _id  ltable_id  rtable_id  \
# 0    2985534       6308       1578
# 1    2764025       5446       1461
# 2    2075992       6618       1097
# 3    1360833       5152        719
# 4    1477807       4420        781
# 5     923422       2080        488
# 6    1812222       2777        958
# 7    1737633       7436        918
# 8    1836506       1107        971
# 9    2506562       4480       1325
# 10   2664057       6257       1408
# 11   1737660       7500        918
# 12    508026       5270        268
# 13   1094610       7224        578
# 14   1253136       5483        662
# 15   1095107        675        579
# 16   2665002       1819       1409
# 17   1407132        698        744
# 18    542932        661        287
# 19    892708        510        472
# 20   1867844       5743        987
# ...

# %%
#label first 200 tuples
g0 = em.label_table(G, 'name', verbose=False)
#G1_labeled = em.label_table(G1, 'name', verbose=True)
# Out:
# Column name (name) is not present in dataframe
# For some attr. values in (rtable_id) in the foreign table there are no values in (id) in the base table
# Candset does not satisfy foreign key constraint with the right table
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-17-010ee253bd1f> in <module>()
#       1 #label first 200 tuples
# ----> 2 g0 = em.label_table(G, 'name', verbose=False)
#       3 #G1_labeled = em.label_table(G1, 'name', verbose=True)
#
# /Users/andrew/anaconda/lib/python3.5/site-packages/py_entitymatching-0.1.0-py3.5.egg/py_entitymatching/labeler/labeler.py in label_table(table, label_column_name, verbose)
#      51     # Validate the input parameters: check input types, check the metadata
#      52     # for the input DataFrame as it will get copied to the labeled DataFrame
# ---> 53     _validate_inputs(table, label_column_name, verbose)
# ...
