# %%
from ipykernel.kernelspec import RESOURCES
import magellan as mg
# Out:
# DEBUG:Cloud:Log file (/home/ubuntuvm/.picloud/cloud.log) opened

# %%
mg.init_jvm()
# Out:
# True

# %%
# Input tables
A = mg.read_csv('tableA.csv', key='ID')
B = mg.read_csv('tableB.csv', key='ID')

# %%
A.head(2)
# Out:
#    ID                          name  votes  rating           phone  \
# 0   0            Strings Ramen Shop     15     3.1  (312) 374-3450
# 1   1  Francesco's Hole In The Wall    179     4.0  (847) 272-0155
#
#                           address    zip              cuisine  reviewcount
# 0  2141 S. Archer Avenue, Chicago  60616  Asian,Chinese,Ramen            2
# 1            254 Skokie Boulevard  60062              Italian            6

# %%
B.head(2)
# Out:
#    ID                       name  votes  rating           phone  \
# 0   0             Patinoâ€™s Grill     35       5  (773) 280-9562
# 1   1  Grandma Jâ€™s Local Kitchen    188       4  (773) 227-3626
#
#                  address    zip                 cuisine
# 0  2943 W Irving Park Rd  60618  American (Traditional)
# 1      1552 N Kedzie Ave  60651      Breakfast & Brunch

# %%
# Stage2 Blocking: stored in tableC.csv
C = mg.read_csv('tableC.csv', ltable=A, rtable=B)
len(C)
# Out:
# 10630

# %%
# Plan

# 1. Sample candidate set --> S
# 2. Label S --> G
# 3. Split G into development set I, and evaluation set J
# 4. Select best learning-based matcher Y, using I 
# 5. Add triggers to Y ---> Z
# 6. Evaluate Z using J

# %%
# Sample the candidate set
S = mg.sample_table(C, 450)

# %%
# Label S
G = mg.label_table(S, 'gold')
G.to_csv('label.csv')
# Out:
# True

# %%
# User labeled table
G = mg.read_csv('gold_init.csv', ltable=A, rtable=B)
len(G)
# Out:
# 450

# %%
# Split G into development (I) and evaluation (J)
IJ = mg.train_test_split(G, train_proportion=0.7)
I = IJ['train']
J = IJ['test']
(len(I), len(J))
# Out:
# (315, 135)

# %%
# Selecting the best learning-based matcher using I

# Plan 
# 1. Create a set of ML-matchers
# 2. Generate features --> feature_table
# 3. Extract feature vectors using I and feature_table
# 4. Select best learning-based matcher using CV
# 5. Debug the selected matcher (and repeat the above steps)

# %%
# Create a set of ML-matchers
dt = mg.DTMatcher(name='DecisionTree', random_state=0)
svm = mg.SVMMatcher(name='SVM')
rf = mg.RFMatcher(name='RF', random_state=0)
nb = mg.NBMatcher(name='NB')
lg = mg.LogRegMatcher(name='LogReg')
ln = mg.LinRegMatcher(name='LinReg')

# %%
# Names of the matchers
(dt.name, svm.name, rf.name, nb.name, lg.name, ln.name)
# Out:
# ('DecisionTree', 'SVM', 'RF', 'NB', 'LogReg', 'LinReg')

# %%
# Generate features
feat_table = mg.get_features_for_matching(A, B)
feat_table
# Out:
#                            feature_name left_attribute right_attribute  \
# 0                             ID_ID_exm             ID              ID
# 1                             ID_ID_anm             ID              ID
# 2                             ID_ID_lev             ID              ID
# 3             name_name_jac_qgm_3_qgm_3           name            name
# 4         name_name_cos_dlm_dc0_dlm_dc0           name            name
# 5         name_name_jac_dlm_dc0_dlm_dc0           name            name
# 6                         name_name_mel           name            name
# 7                         name_name_lev           name            name
# 8                         name_name_nmw           name            name
# 9                          name_name_sw           name            name
# 10                        name_name_swg           name            name
# 11                      votes_votes_exm          votes           votes
# 12                      votes_votes_anm          votes           votes
# 13                      votes_votes_lev          votes           votes
# 14                    rating_rating_exm         rating          rating
# 15                    rating_rating_anm         rating          rating
# 16                    rating_rating_lev         rating          rating
# 17          phone_phone_jac_qgm_3_qgm_3          phone           phone
# 18      phone_phone_cos_dlm_dc0_dlm_dc0          phone           phone
# 19      phone_phone_jac_dlm_dc0_dlm_dc0          phone           phone
# 20                      phone_phone_mel          phone           phone
# 21                      phone_phone_lev          phone           phone
# 22                      phone_phone_nmw          phone           phone
# 23                       phone_phone_sw          phone           phone
# 24                      phone_phone_swg          phone           phone
# 25      address_address_jac_qgm_3_qgm_3        address         address
# 26  address_address_cos_dlm_dc0_dlm_dc0        address         address
# 27  address_address_jac_dlm_dc0_dlm_dc0        address         address
# 28                  address_address_mel        address         address
# 29                  address_address_lev        address         address
# 30                  address_address_nmw        address         address
# 31                   address_address_sw        address         address
# 32                  address_address_swg        address         address
# 33                          zip_zip_exm            zip             zip
# 34                          zip_zip_anm            zip             zip
# 35                          zip_zip_lev            zip             zip
# 36      cuisine_cuisine_jac_qgm_3_qgm_3        cuisine         cuisine
# 37  cuisine_cuisine_cos_dlm_dc0_dlm_dc0        cuisine         cuisine
# 38  cuisine_cuisine_jac_dlm_dc0_dlm_dc0        cuisine         cuisine
# 39                  cuisine_cuisine_mel        cuisine         cuisine
# 40                  cuisine_cuisine_lev        cuisine         cuisine
# 41                  cuisine_cuisine_nmw        cuisine         cuisine
# 42                   cuisine_cuisine_sw        cuisine         cuisine
# 43                  cuisine_cuisine_swg        cuisine         cuisine
#
#    left_attr_tokenizer right_attr_tokenizer           simfunction  \
# 0                 None                 None           exact_match
# 1                 None                 None              abs_norm
# 2                 None                 None                   lev
# 3                qgm_3                qgm_3               jaccard
# 4              dlm_dc0              dlm_dc0                cosine
# 5              dlm_dc0              dlm_dc0               jaccard
# 6                 None                 None           monge_elkan
# 7                 None                 None                   lev
# 8                 None                 None      needleman_wunsch
# 9                 None                 None        smith_waterman
# 10                None                 None  smith_waterman_gotoh
# 11                None                 None           exact_match
# 12                None                 None              abs_norm
# 13                None                 None                   lev
# 14                None                 None           exact_match
# 15                None                 None              abs_norm
# 16                None                 None                   lev
# 17               qgm_3                qgm_3               jaccard
# 18             dlm_dc0              dlm_dc0                cosine
# 19             dlm_dc0              dlm_dc0               jaccard
# 20                None                 None           monge_elkan
# 21                None                 None                   lev
# 22                None                 None      needleman_wunsch
# 23                None                 None        smith_waterman
# 24                None                 None  smith_waterman_gotoh
# 25               qgm_3                qgm_3               jaccard
# 26             dlm_dc0              dlm_dc0                cosine
# 27             dlm_dc0              dlm_dc0               jaccard
# 28                None                 None           monge_elkan
# 29                None                 None                   lev
# 30                None                 None      needleman_wunsch
# 31                None                 None        smith_waterman
# 32                None                 None  smith_waterman_gotoh
# 33                None                 None           exact_match
# 34                None                 None              abs_norm
# 35                None                 None                   lev
# 36               qgm_3                qgm_3               jaccard
# 37             dlm_dc0              dlm_dc0                cosine
# 38             dlm_dc0              dlm_dc0               jaccard
# 39                None                 None           monge_elkan
# 40                None                 None                   lev
# 41                None                 None      needleman_wunsch
# 42                None                 None        smith_waterman
# 43                None                 None  smith_waterman_gotoh
#
#                                              function  \
# 0              <function ID_ID_exm at 0x7feee96ab500>
# 1              <function ID_ID_anm at 0x7feee96ab230>
# 2              <function ID_ID_lev at 0x7feee96ab848>
# 3   <function name_name_jac_qgm_3_qgm_3 at 0x7feee...
# 4   <function name_name_cos_dlm_dc0_dlm_dc0 at 0x7...
# 5   <function name_name_jac_dlm_dc0_dlm_dc0 at 0x7...
# 6          <function name_name_mel at 0x7feee96aba28>
# 7          <function name_name_lev at 0x7feee96abaa0>
# 8          <function name_name_nmw at 0x7feee96abb18>
# 9           <function name_name_sw at 0x7feee96abb90>
# 10         <function name_name_swg at 0x7feee96abc08>
# 11       <function votes_votes_exm at 0x7feee96abc80>
# 12       <function votes_votes_anm at 0x7feee96abcf8>
# 13       <function votes_votes_lev at 0x7feee96abd70>
# 14     <function rating_rating_exm at 0x7feee96abde8>
# 15     <function rating_rating_anm at 0x7feee96abe60>
# 16     <function rating_rating_lev at 0x7feee96abed8>
# 17  <function phone_phone_jac_qgm_3_qgm_3 at 0x7fe...
# 18  <function phone_phone_cos_dlm_dc0_dlm_dc0 at 0...
# 19  <function phone_phone_jac_dlm_dc0_dlm_dc0 at 0...
# 20       <function phone_phone_mel at 0x7feee913f050>
# 21       <function phone_phone_lev at 0x7feee913f0c8>
# 22       <function phone_phone_nmw at 0x7feee913f140>
# 23        <function phone_phone_sw at 0x7feee913f1b8>
# 24       <function phone_phone_swg at 0x7feee913f230>
# 25  <function address_address_jac_qgm_3_qgm_3 at 0...
# 26  <function address_address_cos_dlm_dc0_dlm_dc0 ...
# 27  <function address_address_jac_dlm_dc0_dlm_dc0 ...
# 28   <function address_address_mel at 0x7feee913f410>
# 29   <function address_address_lev at 0x7feee913f488>
# 30   <function address_address_nmw at 0x7feee913f500>
# 31    <function address_address_sw at 0x7feee913f578>
# 32   <function address_address_swg at 0x7feee913f5f0>
# 33           <function zip_zip_exm at 0x7feee913f668>
# 34           <function zip_zip_anm at 0x7feee913f6e0>
# 35           <function zip_zip_lev at 0x7feee913f758>
# 36  <function cuisine_cuisine_jac_qgm_3_qgm_3 at 0...
# 37  <function cuisine_cuisine_cos_dlm_dc0_dlm_dc0 ...
# 38  <function cuisine_cuisine_jac_dlm_dc0_dlm_dc0 ...
# 39   <function cuisine_cuisine_mel at 0x7feee913f938>
# 40   <function cuisine_cuisine_lev at 0x7feee913f9b0>
# 41   <function cuisine_cuisine_nmw at 0x7feee913fa28>
# 42    <function cuisine_cuisine_sw at 0x7feee913faa0>
# 43   <function cuisine_cuisine_swg at 0x7feee913fb18>
#
#                                       function_source
# 0   from magellan.feature.simfunctions import *\nf...
# 1   from magellan.feature.simfunctions import *\nf...
# 2   from magellan.feature.simfunctions import *\nf...
# 3   from magellan.feature.simfunctions import *\nf...
# 4   from magellan.feature.simfunctions import *\nf...
# 5   from magellan.feature.simfunctions import *\nf...
# 6   from magellan.feature.simfunctions import *\nf...
# 7   from magellan.feature.simfunctions import *\nf...
# 8   from magellan.feature.simfunctions import *\nf...
# 9   from magellan.feature.simfunctions import *\nf...
# 10  from magellan.feature.simfunctions import *\nf...
# 11  from magellan.feature.simfunctions import *\nf...
# 12  from magellan.feature.simfunctions import *\nf...
# 13  from magellan.feature.simfunctions import *\nf...
# 14  from magellan.feature.simfunctions import *\nf...
# 15  from magellan.feature.simfunctions import *\nf...
# 16  from magellan.feature.simfunctions import *\nf...
# 17  from magellan.feature.simfunctions import *\nf...
# 18  from magellan.feature.simfunctions import *\nf...
# 19  from magellan.feature.simfunctions import *\nf...
# 20  from magellan.feature.simfunctions import *\nf...
# 21  from magellan.feature.simfunctions import *\nf...
# 22  from magellan.feature.simfunctions import *\nf...
# 23  from magellan.feature.simfunctions import *\nf...
# 24  from magellan.feature.simfunctions import *\nf...
# 25  from magellan.feature.simfunctions import *\nf...
# 26  from magellan.feature.simfunctions import *\nf...
# 27  from magellan.feature.simfunctions import *\nf...
# 28  from magellan.feature.simfunctions import *\nf...
# 29  from magellan.feature.simfunctions import *\nf...
# 30  from magellan.feature.simfunctions import *\nf...
# 31  from magellan.feature.simfunctions import *\nf...
# 32  from magellan.feature.simfunctions import *\nf...
# 33  from magellan.feature.simfunctions import *\nf...
# 34  from magellan.feature.simfunctions import *\nf...
# 35  from magellan.feature.simfunctions import *\nf...
# 36  from magellan.feature.simfunctions import *\nf...
# 37  from magellan.feature.simfunctions import *\nf...
# 38  from magellan.feature.simfunctions import *\nf...
# 39  from magellan.feature.simfunctions import *\nf...
# 40  from magellan.feature.simfunctions import *\nf...
# 41  from magellan.feature.simfunctions import *\nf...
# 42  from magellan.feature.simfunctions import *\nf...
# 43  from magellan.feature.simfunctions import *\nf...

# %%
mg._match_s
# Out:
# {'abs_norm': <function magellan.feature.simfunctions.abs_norm>,
#  'cosine': <function magellan.feature.simfunctions.cosine>,
#  'exact_match': <function magellan.feature.simfunctions.exact_match>,
#  'jaccard': <function magellan.feature.simfunctions.jaccard>,
#  'jaro': <function magellan.feature.simfunctions.jaro>,
#  'jaro_winkler': <function magellan.feature.simfunctions.jaro_winkler>,
#  'lev': <function magellan.feature.simfunctions.lev>,
#  'monge_elkan': <function magellan.feature.simfunctions.monge_elkan>,
#  'needleman_wunsch': <function magellan.feature.simfunctions.needleman_wunsch>,
#  'rel_diff': <function magellan.feature.simfunctions.rel_diff>,
#  'smith_waterman': <function magellan.feature.simfunctions.smith_waterman>,
#  'smith_waterman_gotoh': <function magellan.feature.simfunctions.smith_waterman_gotoh>,
#  'soundex': <function magellan.feature.simfunctions.soundex>}

# %%
mg._match_t
# Out:
# {'dlm_dc0': <function magellan.feature.tokenizers.tok_delim>,
#  'qgm_2': <function magellan.feature.tokenizers.tok_qgram>,
#  'qgm_3': <function magellan.feature.tokenizers.tok_qgram>}

# %%
mg._match_c['corres']
# Out:
# [('ID', 'ID'),
#  ('name', 'name'),
#  ('votes', 'votes'),
#  ('rating', 'rating'),
#  ('phone', 'phone'),
#  ('address', 'address'),
#  ('zip', 'zip'),
#  ('cuisine', 'cuisine')]

# %%
# Select 'address' related features
feat_subset_iter1 = feat_table[25:33]
feat_subset_iter1
# Out:
#                            feature_name left_attribute right_attribute  \
# 25      address_address_jac_qgm_3_qgm_3        address         address
# 26  address_address_cos_dlm_dc0_dlm_dc0        address         address
# 27  address_address_jac_dlm_dc0_dlm_dc0        address         address
# 28                  address_address_mel        address         address
# 29                  address_address_lev        address         address
# 30                  address_address_nmw        address         address
# 31                   address_address_sw        address         address
# 32                  address_address_swg        address         address
#
#    left_attr_tokenizer right_attr_tokenizer           simfunction  \
# 25               qgm_3                qgm_3               jaccard
# 26             dlm_dc0              dlm_dc0                cosine
# 27             dlm_dc0              dlm_dc0               jaccard
# 28                None                 None           monge_elkan
# 29                None                 None                   lev
# 30                None                 None      needleman_wunsch
# 31                None                 None        smith_waterman
# 32                None                 None  smith_waterman_gotoh
#
#                                              function  \
# 25  <function address_address_jac_qgm_3_qgm_3 at 0...
# 26  <function address_address_cos_dlm_dc0_dlm_dc0 ...
# 27  <function address_address_jac_dlm_dc0_dlm_dc0 ...
# 28   <function address_address_mel at 0x7feee913f410>
# 29   <function address_address_lev at 0x7feee913f488>
# 30   <function address_address_nmw at 0x7feee913f500>
# 31    <function address_address_sw at 0x7feee913f578>
# 32   <function address_address_swg at 0x7feee913f5f0>
#
#                                       function_source
# 25  from magellan.feature.simfunctions import *\nf...
# 26  from magellan.feature.simfunctions import *\nf...
# 27  from magellan.feature.simfunctions import *\nf...
# 28  from magellan.feature.simfunctions import *\nf...
# 29  from magellan.feature.simfunctions import *\nf...
# 30  from magellan.feature.simfunctions import *\nf...
# 31  from magellan.feature.simfunctions import *\nf...
# 32  from magellan.feature.simfunctions import *\nf...

# %%
# Get feature vectors
K = mg.extract_feature_vecs(I, feature_table=feat_subset_iter1, attrs_after='gold')

# %%
# impute K
K.fillna(0, inplace=True)
K.head()
# Out:
#    _id  ltable.id  rtable.id  address_address_jac_qgm_3_qgm_3  \
# 0    0       4451       2989                         1.000000
# 1    1       4303       1976                         0.560000
# 2    2       1405        645                         0.026316
# 3    3       3932       1869                         0.600000
# 4    4       3450       1580                         0.684211
#
#    address_address_cos_dlm_dc0_dlm_dc0  address_address_jac_dlm_dc0_dlm_dc0  \
# 0                              1.00000                                  1.0
# 1                              0.57735                                  0.4
# 2                              0.00000                                  0.0
# 3                              0.75000                                  0.6
# 4                              0.75000                                  0.6
#
#    address_address_mel  address_address_lev  address_address_nmw  \
# 0             1.000000             1.000000             1.000000
# 1             0.800000             0.739130             0.847826
# 2             0.200000             0.214286             0.500000
# 3             0.777778             0.777778             0.888889
# 4             0.833333             0.833333             0.916667
#
#    address_address_sw  address_address_swg  gold
# 0            1.000000             1.000000     1
# 1            0.800000             0.800000     0
# 2            0.200000             0.200000     0
# 3            0.805556             0.777778     0
# 4            0.833333             0.833333     0

# %%
# select the best ML matcher using CV
result = mg.select_matcher([dt, rf, svm, nb, lg, ln], table=K, 
        exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
        target_attr='gold', metric='precision', random_state=0)

# %%
result['selected_matcher']

# %%
result['cv_stats']
# Out:
#            Name                                            Matcher  Num folds  \
# 0  DecisionTree  <magellan.matcher.dtmatcher.DTMatcher object a...          5
# 1            RF  <magellan.matcher.rfmatcher.RFMatcher object a...          5
# 2           SVM  <magellan.matcher.svmmatcher.SVMMatcher object...          5
# 3            NB  <magellan.matcher.nbmatcher.NBMatcher object a...          5
# 4        LogReg  <magellan.matcher.logregmatcher.LogRegMatcher ...          5
# 5        LinReg  <magellan.matcher.linregmatcher.LinRegMatcher ...          5
#
#      Fold 1    Fold 2    Fold 3    Fold 4    Fold 5  Mean score
# 0  0.909091  0.615385  0.600000  0.777778  0.882353    0.756921
# 1  0.900000  0.800000  0.857143  0.714286  0.937500    0.841786
# 2  1.000000  1.000000  1.000000  0.714286  0.000000    0.742857
# 3  0.777778  0.380952  0.533333  0.312500  0.809524    0.562817
# 4  1.000000  0.875000  0.800000  0.714286  1.000000    0.877857
# 5  0.846154  0.666667  0.875000  0.545455  0.944444    0.775544

# %%
UV = mg.train_test_split(K, train_proportion=0.5, random_state=0)
U = UV['train']
V = UV['test']
# 1. Train RF using U
# 2. Predict V using DT
# 3. Evaluate predictions
dt.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = dt.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 82.76% (24/29)
# Recall : 75.0% (24/32)
# F1 : 78.69%
# False positives : 5 (out of 29 positive predictions)
# False negatives : 8 (out of 129 negative predictions)

# %%
rf.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = rf.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 91.3% (21/23)
# Recall : 65.63% (21/32)
# F1 : 76.36%
# False positives : 2 (out of 23 positive predictions)
# False negatives : 11 (out of 135 negative predictions)

# %%
svm.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = svm.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 0.0% (0/0)
# Recall : 0.0% (0/32)
# F1 : 0.0%
# False positives : 0 (out of 0 positive predictions)
# False negatives : 32 (out of 158 negative predictions)

# %%
nb.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = nb.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 54.72% (29/53)
# Recall : 90.63% (29/32)
# F1 : 68.24%
# False positives : 24 (out of 53 positive predictions)
# False negatives : 3 (out of 105 negative predictions)

# %%
lg.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = lg.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (12/12)
# Recall : 37.5% (12/32)
# F1 : 54.55%
# False positives : 0 (out of 12 positive predictions)
# False negatives : 20 (out of 146 negative predictions)

# %%
ln.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = ln.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 78.13% (25/32)
# Recall : 78.13% (25/32)
# F1 : 78.13%
# False positives : 7 (out of 32 positive predictions)
# False negatives : 7 (out of 126 negative predictions)

# %%
# Debug random forest
# Split feature vectors to train and test
UV = mg.train_test_split(K, train_proportion=0.5, random_state=0)
U = UV['train']
V = UV['test']

# %%
mg.vis_debug_rf(rf, U, V, 
        exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
        target_attr='gold')
# Inspect false positives and take actions:
# removed 6 tuples as they had same address, but different name and phone numbers

# %%
#New G
G = mg.read_csv('gold_final.csv', ltable=A, rtable=B)
# Split G into development (I) and evaluation (J)
IJ = mg.train_test_split(G, train_proportion=0.7)
I = IJ['train']
J = IJ['test']
(len(G),len(I), len(J))
# Out:
# (444, 310, 134)

# %%
K = mg.extract_feature_vecs(I, feature_table=feat_subset_iter1, attrs_after='gold')
K.fillna(0, inplace=True)
K.head()
# Out:
#    _id  ltable.id  rtable.id  address_address_jac_qgm_3_qgm_3  \
# 0    0       5208       2507                         0.514286
# 1    1       5497       2616                         0.500000
# 2    2       3753       2373                         0.666667
# 3    3       3951       1632                         0.550000
# 4    4       4350       3203                         0.533333
#
#    address_address_cos_dlm_dc0_dlm_dc0  address_address_jac_dlm_dc0_dlm_dc0  \
# 0                             0.755929                             0.571429
# 1                             0.666667                             0.500000
# 2                             0.750000                             0.600000
# 3                             0.333333                             0.200000
# 4                             0.750000                             0.600000
#
#    address_address_mel  address_address_lev  address_address_nmw  \
# 0             1.000000             0.540541             0.540541
# 1             0.714286             0.785714             0.892857
# 2             0.836364             0.863636             0.931818
# 3             0.812500             0.684211             0.763158
# 4             0.769231             0.785714             0.892857
#
#    address_address_sw  address_address_swg  gold
# 0            1.000000             1.000000     1
# 1            0.714286             0.714286     0
# 2            0.840909             0.836364     0
# 3            0.812500             0.812500     0
# 4            0.846154             0.769231     0

# %%
result = mg.select_matcher([dt, rf, svm, nb, lg, ln], table=K,
        exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
        target_attr='gold', metric='precision', random_state=0)
result['selected_matcher']

# %%
result['cv_stats']
# Out:
#            Name                                            Matcher  Num folds  \
# 0  DecisionTree  <magellan.matcher.dtmatcher.DTMatcher object a...          5
# 1            RF  <magellan.matcher.rfmatcher.RFMatcher object a...          5
# 2           SVM  <magellan.matcher.svmmatcher.SVMMatcher object...          5
# 3            NB  <magellan.matcher.nbmatcher.NBMatcher object a...          5
# 4        LogReg  <magellan.matcher.logregmatcher.LogRegMatcher ...          5
# 5        LinReg  <magellan.matcher.linregmatcher.LinRegMatcher ...          5
#
#      Fold 1    Fold 2    Fold 3    Fold 4    Fold 5  Mean score
# 0  0.833333  0.909091  1.000000  0.800000  0.894737    0.887432
# 1  0.909091  0.900000  1.000000  0.800000  1.000000    0.921818
# 2  0.916667  0.900000  1.000000  0.888889  0.809524    0.903016
# 3  0.600000  0.714286  0.736842  0.588235  0.571429    0.642158
# 4  1.000000  1.000000  1.000000  0.875000  0.888889    0.952778
# 5  0.800000  0.923077  1.000000  0.833333  0.739130    0.859108

# %%
UV = mg.train_test_split(K, train_proportion=0.5, random_state=0)
U = UV['train']
V = UV['test']
# 1. Train RF using U
# 2. Predict V using DT
# 3. Evaluate predictions
rf.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = rf.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (28/28)
# Recall : 77.78% (28/36)
# F1 : 87.5%
# False positives : 0 (out of 28 positive predictions)
# False negatives : 8 (out of 127 negative predictions)

# %%
dt.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = dt.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 96.55% (28/29)
# Recall : 77.78% (28/36)
# F1 : 86.15%
# False positives : 1 (out of 29 positive predictions)
# False negatives : 8 (out of 126 negative predictions)

# %%
svm.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = svm.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (10/10)
# Recall : 27.78% (10/36)
# F1 : 43.48%
# False positives : 0 (out of 10 positive predictions)
# False negatives : 26 (out of 145 negative predictions)

# %%
nb.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = nb.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 65.22% (30/46)
# Recall : 83.33% (30/36)
# F1 : 73.17%
# False positives : 16 (out of 46 positive predictions)
# False negatives : 6 (out of 109 negative predictions)

# %%
lg.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = lg.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (21/21)
# Recall : 58.33% (21/36)
# F1 : 73.68%
# False positives : 0 (out of 21 positive predictions)
# False negatives : 15 (out of 134 negative predictions)

# %%
ln.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = ln.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 88.89% (32/36)
# Recall : 88.89% (32/36)
# F1 : 88.89%
# False positives : 4 (out of 36 positive predictions)
# False negatives : 4 (out of 119 negative predictions)

# %%
# Include feature for 'phone'

# %%
feat_table
# Out:
#                            feature_name left_attribute right_attribute  \
# 0                             ID_ID_exm             ID              ID
# 1                             ID_ID_anm             ID              ID
# 2                             ID_ID_lev             ID              ID
# 3             name_name_jac_qgm_3_qgm_3           name            name
# 4         name_name_cos_dlm_dc0_dlm_dc0           name            name
# 5         name_name_jac_dlm_dc0_dlm_dc0           name            name
# 6                         name_name_mel           name            name
# 7                         name_name_lev           name            name
# 8                         name_name_nmw           name            name
# 9                          name_name_sw           name            name
# 10                        name_name_swg           name            name
# 11                      votes_votes_exm          votes           votes
# 12                      votes_votes_anm          votes           votes
# 13                      votes_votes_lev          votes           votes
# 14                    rating_rating_exm         rating          rating
# 15                    rating_rating_anm         rating          rating
# 16                    rating_rating_lev         rating          rating
# 17          phone_phone_jac_qgm_3_qgm_3          phone           phone
# 18      phone_phone_cos_dlm_dc0_dlm_dc0          phone           phone
# 19      phone_phone_jac_dlm_dc0_dlm_dc0          phone           phone
# 20                      phone_phone_mel          phone           phone
# 21                      phone_phone_lev          phone           phone
# 22                      phone_phone_nmw          phone           phone
# 23                       phone_phone_sw          phone           phone
# 24                      phone_phone_swg          phone           phone
# 25      address_address_jac_qgm_3_qgm_3        address         address
# 26  address_address_cos_dlm_dc0_dlm_dc0        address         address
# 27  address_address_jac_dlm_dc0_dlm_dc0        address         address
# 28                  address_address_mel        address         address
# 29                  address_address_lev        address         address
# 30                  address_address_nmw        address         address
# 31                   address_address_sw        address         address
# 32                  address_address_swg        address         address
# 33                          zip_zip_exm            zip             zip
# 34                          zip_zip_anm            zip             zip
# 35                          zip_zip_lev            zip             zip
# 36      cuisine_cuisine_jac_qgm_3_qgm_3        cuisine         cuisine
# 37  cuisine_cuisine_cos_dlm_dc0_dlm_dc0        cuisine         cuisine
# 38  cuisine_cuisine_jac_dlm_dc0_dlm_dc0        cuisine         cuisine
# 39                  cuisine_cuisine_mel        cuisine         cuisine
# 40                  cuisine_cuisine_lev        cuisine         cuisine
# 41                  cuisine_cuisine_nmw        cuisine         cuisine
# 42                   cuisine_cuisine_sw        cuisine         cuisine
# 43                  cuisine_cuisine_swg        cuisine         cuisine
#
#    left_attr_tokenizer right_attr_tokenizer           simfunction  \
# 0                 None                 None           exact_match
# 1                 None                 None              abs_norm
# 2                 None                 None                   lev
# 3                qgm_3                qgm_3               jaccard
# 4              dlm_dc0              dlm_dc0                cosine
# 5              dlm_dc0              dlm_dc0               jaccard
# 6                 None                 None           monge_elkan
# 7                 None                 None                   lev
# 8                 None                 None      needleman_wunsch
# 9                 None                 None        smith_waterman
# 10                None                 None  smith_waterman_gotoh
# 11                None                 None           exact_match
# 12                None                 None              abs_norm
# 13                None                 None                   lev
# 14                None                 None           exact_match
# 15                None                 None              abs_norm
# 16                None                 None                   lev
# 17               qgm_3                qgm_3               jaccard
# 18             dlm_dc0              dlm_dc0                cosine
# 19             dlm_dc0              dlm_dc0               jaccard
# 20                None                 None           monge_elkan
# 21                None                 None                   lev
# 22                None                 None      needleman_wunsch
# 23                None                 None        smith_waterman
# 24                None                 None  smith_waterman_gotoh
# 25               qgm_3                qgm_3               jaccard
# 26             dlm_dc0              dlm_dc0                cosine
# 27             dlm_dc0              dlm_dc0               jaccard
# 28                None                 None           monge_elkan
# 29                None                 None                   lev
# 30                None                 None      needleman_wunsch
# 31                None                 None        smith_waterman
# 32                None                 None  smith_waterman_gotoh
# 33                None                 None           exact_match
# 34                None                 None              abs_norm
# 35                None                 None                   lev
# 36               qgm_3                qgm_3               jaccard
# 37             dlm_dc0              dlm_dc0                cosine
# 38             dlm_dc0              dlm_dc0               jaccard
# 39                None                 None           monge_elkan
# 40                None                 None                   lev
# 41                None                 None      needleman_wunsch
# 42                None                 None        smith_waterman
# 43                None                 None  smith_waterman_gotoh
#
#                                              function  \
# 0              <function ID_ID_exm at 0x7feee96ab500>
# 1              <function ID_ID_anm at 0x7feee96ab230>
# 2              <function ID_ID_lev at 0x7feee96ab848>
# 3   <function name_name_jac_qgm_3_qgm_3 at 0x7feee...
# 4   <function name_name_cos_dlm_dc0_dlm_dc0 at 0x7...
# 5   <function name_name_jac_dlm_dc0_dlm_dc0 at 0x7...
# 6          <function name_name_mel at 0x7feee96aba28>
# 7          <function name_name_lev at 0x7feee96abaa0>
# 8          <function name_name_nmw at 0x7feee96abb18>
# 9           <function name_name_sw at 0x7feee96abb90>
# 10         <function name_name_swg at 0x7feee96abc08>
# 11       <function votes_votes_exm at 0x7feee96abc80>
# 12       <function votes_votes_anm at 0x7feee96abcf8>
# 13       <function votes_votes_lev at 0x7feee96abd70>
# 14     <function rating_rating_exm at 0x7feee96abde8>
# 15     <function rating_rating_anm at 0x7feee96abe60>
# 16     <function rating_rating_lev at 0x7feee96abed8>
# 17  <function phone_phone_jac_qgm_3_qgm_3 at 0x7fe...
# 18  <function phone_phone_cos_dlm_dc0_dlm_dc0 at 0...
# 19  <function phone_phone_jac_dlm_dc0_dlm_dc0 at 0...
# 20       <function phone_phone_mel at 0x7feee913f050>
# 21       <function phone_phone_lev at 0x7feee913f0c8>
# 22       <function phone_phone_nmw at 0x7feee913f140>
# 23        <function phone_phone_sw at 0x7feee913f1b8>
# 24       <function phone_phone_swg at 0x7feee913f230>
# 25  <function address_address_jac_qgm_3_qgm_3 at 0...
# 26  <function address_address_cos_dlm_dc0_dlm_dc0 ...
# 27  <function address_address_jac_dlm_dc0_dlm_dc0 ...
# 28   <function address_address_mel at 0x7feee913f410>
# 29   <function address_address_lev at 0x7feee913f488>
# 30   <function address_address_nmw at 0x7feee913f500>
# 31    <function address_address_sw at 0x7feee913f578>
# 32   <function address_address_swg at 0x7feee913f5f0>
# 33           <function zip_zip_exm at 0x7feee913f668>
# 34           <function zip_zip_anm at 0x7feee913f6e0>
# 35           <function zip_zip_lev at 0x7feee913f758>
# 36  <function cuisine_cuisine_jac_qgm_3_qgm_3 at 0...
# 37  <function cuisine_cuisine_cos_dlm_dc0_dlm_dc0 ...
# 38  <function cuisine_cuisine_jac_dlm_dc0_dlm_dc0 ...
# 39   <function cuisine_cuisine_mel at 0x7feee913f938>
# 40   <function cuisine_cuisine_lev at 0x7feee913f9b0>
# 41   <function cuisine_cuisine_nmw at 0x7feee913fa28>
# 42    <function cuisine_cuisine_sw at 0x7feee913faa0>
# 43   <function cuisine_cuisine_swg at 0x7feee913fb18>
#
#                                       function_source
# 0   from magellan.feature.simfunctions import *\nf...
# 1   from magellan.feature.simfunctions import *\nf...
# 2   from magellan.feature.simfunctions import *\nf...
# 3   from magellan.feature.simfunctions import *\nf...
# 4   from magellan.feature.simfunctions import *\nf...
# 5   from magellan.feature.simfunctions import *\nf...
# 6   from magellan.feature.simfunctions import *\nf...
# 7   from magellan.feature.simfunctions import *\nf...
# 8   from magellan.feature.simfunctions import *\nf...
# 9   from magellan.feature.simfunctions import *\nf...
# 10  from magellan.feature.simfunctions import *\nf...
# 11  from magellan.feature.simfunctions import *\nf...
# 12  from magellan.feature.simfunctions import *\nf...
# 13  from magellan.feature.simfunctions import *\nf...
# 14  from magellan.feature.simfunctions import *\nf...
# 15  from magellan.feature.simfunctions import *\nf...
# 16  from magellan.feature.simfunctions import *\nf...
# 17  from magellan.feature.simfunctions import *\nf...
# 18  from magellan.feature.simfunctions import *\nf...
# 19  from magellan.feature.simfunctions import *\nf...
# 20  from magellan.feature.simfunctions import *\nf...
# 21  from magellan.feature.simfunctions import *\nf...
# 22  from magellan.feature.simfunctions import *\nf...
# 23  from magellan.feature.simfunctions import *\nf...
# 24  from magellan.feature.simfunctions import *\nf...
# 25  from magellan.feature.simfunctions import *\nf...
# 26  from magellan.feature.simfunctions import *\nf...
# 27  from magellan.feature.simfunctions import *\nf...
# 28  from magellan.feature.simfunctions import *\nf...
# 29  from magellan.feature.simfunctions import *\nf...
# 30  from magellan.feature.simfunctions import *\nf...
# 31  from magellan.feature.simfunctions import *\nf...
# 32  from magellan.feature.simfunctions import *\nf...
# 33  from magellan.feature.simfunctions import *\nf...
# 34  from magellan.feature.simfunctions import *\nf...
# 35  from magellan.feature.simfunctions import *\nf...
# 36  from magellan.feature.simfunctions import *\nf...
# 37  from magellan.feature.simfunctions import *\nf...
# 38  from magellan.feature.simfunctions import *\nf...
# 39  from magellan.feature.simfunctions import *\nf...
# 40  from magellan.feature.simfunctions import *\nf...
# 41  from magellan.feature.simfunctions import *\nf...
# 42  from magellan.feature.simfunctions import *\nf...
# 43  from magellan.feature.simfunctions import *\nf...

# %%
# Select 'phone'  + 'address' related features
feat_subset_iter2 = feat_table[17:33]

# %%
feat_subset_iter2
# Out:
#                            feature_name left_attribute right_attribute  \
# 17          phone_phone_jac_qgm_3_qgm_3          phone           phone
# 18      phone_phone_cos_dlm_dc0_dlm_dc0          phone           phone
# 19      phone_phone_jac_dlm_dc0_dlm_dc0          phone           phone
# 20                      phone_phone_mel          phone           phone
# 21                      phone_phone_lev          phone           phone
# 22                      phone_phone_nmw          phone           phone
# 23                       phone_phone_sw          phone           phone
# 24                      phone_phone_swg          phone           phone
# 25      address_address_jac_qgm_3_qgm_3        address         address
# 26  address_address_cos_dlm_dc0_dlm_dc0        address         address
# 27  address_address_jac_dlm_dc0_dlm_dc0        address         address
# 28                  address_address_mel        address         address
# 29                  address_address_lev        address         address
# 30                  address_address_nmw        address         address
# 31                   address_address_sw        address         address
# 32                  address_address_swg        address         address
#
#    left_attr_tokenizer right_attr_tokenizer           simfunction  \
# 17               qgm_3                qgm_3               jaccard
# 18             dlm_dc0              dlm_dc0                cosine
# 19             dlm_dc0              dlm_dc0               jaccard
# 20                None                 None           monge_elkan
# 21                None                 None                   lev
# 22                None                 None      needleman_wunsch
# 23                None                 None        smith_waterman
# 24                None                 None  smith_waterman_gotoh
# 25               qgm_3                qgm_3               jaccard
# 26             dlm_dc0              dlm_dc0                cosine
# 27             dlm_dc0              dlm_dc0               jaccard
# 28                None                 None           monge_elkan
# 29                None                 None                   lev
# 30                None                 None      needleman_wunsch
# 31                None                 None        smith_waterman
# 32                None                 None  smith_waterman_gotoh
#
#                                              function  \
# 17  <function phone_phone_jac_qgm_3_qgm_3 at 0x7fe...
# 18  <function phone_phone_cos_dlm_dc0_dlm_dc0 at 0...
# 19  <function phone_phone_jac_dlm_dc0_dlm_dc0 at 0...
# 20       <function phone_phone_mel at 0x7feee913f050>
# 21       <function phone_phone_lev at 0x7feee913f0c8>
# 22       <function phone_phone_nmw at 0x7feee913f140>
# 23        <function phone_phone_sw at 0x7feee913f1b8>
# 24       <function phone_phone_swg at 0x7feee913f230>
# 25  <function address_address_jac_qgm_3_qgm_3 at 0...
# 26  <function address_address_cos_dlm_dc0_dlm_dc0 ...
# 27  <function address_address_jac_dlm_dc0_dlm_dc0 ...
# 28   <function address_address_mel at 0x7feee913f410>
# 29   <function address_address_lev at 0x7feee913f488>
# 30   <function address_address_nmw at 0x7feee913f500>
# 31    <function address_address_sw at 0x7feee913f578>
# 32   <function address_address_swg at 0x7feee913f5f0>
#
#                                       function_source
# 17  from magellan.feature.simfunctions import *\nf...
# 18  from magellan.feature.simfunctions import *\nf...
# 19  from magellan.feature.simfunctions import *\nf...
# 20  from magellan.feature.simfunctions import *\nf...
# 21  from magellan.feature.simfunctions import *\nf...
# 22  from magellan.feature.simfunctions import *\nf...
# 23  from magellan.feature.simfunctions import *\nf...
# 24  from magellan.feature.simfunctions import *\nf...
# 25  from magellan.feature.simfunctions import *\nf...
# 26  from magellan.feature.simfunctions import *\nf...
# 27  from magellan.feature.simfunctions import *\nf...
# 28  from magellan.feature.simfunctions import *\nf...
# 29  from magellan.feature.simfunctions import *\nf...
# 30  from magellan.feature.simfunctions import *\nf...
# 31  from magellan.feature.simfunctions import *\nf...
# 32  from magellan.feature.simfunctions import *\nf...

# %%
# Get new set of features
K = mg.extract_feature_vecs(I, feature_table=feat_subset_iter2, attrs_after='gold')
# impute K
K.fillna(0, inplace=True)

# %%
# Split feature vectors into U and V
UV = mg.train_test_split(K, train_proportion=0.5, random_state=0)
U = UV['train']
V = UV['test']

# %%
# Check whether the added features improves the accuracy in the test set.
# Steps
# 1. Train RF using U
# 2. Predict V using DT
# 3. Evaluate predictions

# %%
# Train RF using U
dt.fit(table=U, 
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'], 
       target_attr='gold')

# %%
# Predict V using rf
P = dt.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'], 
              append=True, target_attr='predicted', inplace=False)

# %%
# Evaluate the predictions
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (35/35)
# Recall : 97.22% (35/36)
# F1 : 98.59%
# False positives : 0 (out of 35 positive predictions)
# False negatives : 1 (out of 120 negative predictions)

# %%
rf.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = rf.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (35/35)
# Recall : 97.22% (35/36)
# F1 : 98.59%
# False positives : 0 (out of 35 positive predictions)
# False negatives : 1 (out of 120 negative predictions)

# %%
svm.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = svm.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (33/33)
# Recall : 91.67% (33/36)
# F1 : 95.65%
# False positives : 0 (out of 33 positive predictions)
# False negatives : 3 (out of 122 negative predictions)

# %%
nb.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = nb.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 94.44% (34/36)
# Recall : 94.44% (34/36)
# F1 : 94.44%
# False positives : 2 (out of 36 positive predictions)
# False negatives : 2 (out of 119 negative predictions)

# %%
lg.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = lg.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (33/33)
# Recall : 91.67% (33/36)
# F1 : 95.65%
# False positives : 0 (out of 33 positive predictions)
# False negatives : 3 (out of 122 negative predictions)

# %%
ln.fit(table=U,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
P = ln.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(P, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (34/34)
# Recall : 94.44% (34/36)
# F1 : 97.14%
# False positives : 0 (out of 34 positive predictions)
# False negatives : 2 (out of 121 negative predictions)

# %%
# Apply cross validation to find if there is a better matcher
result = mg.select_matcher([dt, rf, svm, nb, lg, ln], table=K, 
        exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
        target_attr='gold', metric='f1')

# %%
result['cv_stats']
# Out:
#            Name                                            Matcher  Num folds  \
# 0  DecisionTree  <magellan.matcher.dtmatcher.DTMatcher object a...          5
# 1            RF  <magellan.matcher.rfmatcher.RFMatcher object a...          5
# 2           SVM  <magellan.matcher.svmmatcher.SVMMatcher object...          5
# 3            NB  <magellan.matcher.nbmatcher.NBMatcher object a...          5
# 4        LogReg  <magellan.matcher.logregmatcher.LogRegMatcher ...          5
# 5        LinReg  <magellan.matcher.linregmatcher.LinRegMatcher ...          5
#
#      Fold 1    Fold 2    Fold 3    Fold 4    Fold 5  Mean score
# 0  1.000000  0.956522  0.928571  1.000000  0.960000    0.969019
# 1  0.965517  0.888889  0.960000  0.967742  1.000000    0.956430
# 2  0.857143  0.888889  0.969697  1.000000  1.000000    0.943146
# 3  0.969697  0.952381  0.956522  0.888889  0.960000    0.945498
# 4  0.967742  0.947368  0.962963  1.000000  0.918919    0.959398
# 5  0.941176  0.903226  0.965517  1.000000  0.972973    0.956578

# %%
# Select DT as the best matcher -- Y
# Use phone + address related features

# %%
# Add triggers on top of Y

# 1. Split K into U and V
# 2. Use U,V  + Y to write triggers (examine fp, fn).

# %%
# Split feature vectors to U and V
UV = mg.train_test_split(K, train_proportion=0.5, random_state=0)
U = UV['train']
V = UV['test']

# %%
# Invoke debug interface to check FP and FN
mg.vis_debug_dt(dt, U, V, 
        exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
        target_attr='gold')

# %%
feat_table
# Out:
#                            feature_name left_attribute right_attribute  \
# 0                             ID_ID_exm             ID              ID
# 1                             ID_ID_anm             ID              ID
# 2                             ID_ID_lev             ID              ID
# 3             name_name_jac_qgm_3_qgm_3           name            name
# 4         name_name_cos_dlm_dc0_dlm_dc0           name            name
# 5         name_name_jac_dlm_dc0_dlm_dc0           name            name
# 6                         name_name_mel           name            name
# 7                         name_name_lev           name            name
# 8                         name_name_nmw           name            name
# 9                          name_name_sw           name            name
# 10                        name_name_swg           name            name
# 11                      votes_votes_exm          votes           votes
# 12                      votes_votes_anm          votes           votes
# 13                      votes_votes_lev          votes           votes
# 14                    rating_rating_exm         rating          rating
# 15                    rating_rating_anm         rating          rating
# 16                    rating_rating_lev         rating          rating
# 17          phone_phone_jac_qgm_3_qgm_3          phone           phone
# 18      phone_phone_cos_dlm_dc0_dlm_dc0          phone           phone
# 19      phone_phone_jac_dlm_dc0_dlm_dc0          phone           phone
# 20                      phone_phone_mel          phone           phone
# 21                      phone_phone_lev          phone           phone
# 22                      phone_phone_nmw          phone           phone
# 23                       phone_phone_sw          phone           phone
# 24                      phone_phone_swg          phone           phone
# 25      address_address_jac_qgm_3_qgm_3        address         address
# 26  address_address_cos_dlm_dc0_dlm_dc0        address         address
# 27  address_address_jac_dlm_dc0_dlm_dc0        address         address
# 28                  address_address_mel        address         address
# 29                  address_address_lev        address         address
# 30                  address_address_nmw        address         address
# 31                   address_address_sw        address         address
# 32                  address_address_swg        address         address
# 33                          zip_zip_exm            zip             zip
# 34                          zip_zip_anm            zip             zip
# 35                          zip_zip_lev            zip             zip
# 36      cuisine_cuisine_jac_qgm_3_qgm_3        cuisine         cuisine
# 37  cuisine_cuisine_cos_dlm_dc0_dlm_dc0        cuisine         cuisine
# 38  cuisine_cuisine_jac_dlm_dc0_dlm_dc0        cuisine         cuisine
# 39                  cuisine_cuisine_mel        cuisine         cuisine
# 40                  cuisine_cuisine_lev        cuisine         cuisine
# 41                  cuisine_cuisine_nmw        cuisine         cuisine
# 42                   cuisine_cuisine_sw        cuisine         cuisine
# 43                  cuisine_cuisine_swg        cuisine         cuisine
#
#    left_attr_tokenizer right_attr_tokenizer           simfunction  \
# 0                 None                 None           exact_match
# 1                 None                 None              abs_norm
# 2                 None                 None                   lev
# 3                qgm_3                qgm_3               jaccard
# 4              dlm_dc0              dlm_dc0                cosine
# 5              dlm_dc0              dlm_dc0               jaccard
# 6                 None                 None           monge_elkan
# 7                 None                 None                   lev
# 8                 None                 None      needleman_wunsch
# 9                 None                 None        smith_waterman
# 10                None                 None  smith_waterman_gotoh
# 11                None                 None           exact_match
# 12                None                 None              abs_norm
# 13                None                 None                   lev
# 14                None                 None           exact_match
# 15                None                 None              abs_norm
# 16                None                 None                   lev
# 17               qgm_3                qgm_3               jaccard
# 18             dlm_dc0              dlm_dc0                cosine
# 19             dlm_dc0              dlm_dc0               jaccard
# 20                None                 None           monge_elkan
# 21                None                 None                   lev
# 22                None                 None      needleman_wunsch
# 23                None                 None        smith_waterman
# 24                None                 None  smith_waterman_gotoh
# 25               qgm_3                qgm_3               jaccard
# 26             dlm_dc0              dlm_dc0                cosine
# 27             dlm_dc0              dlm_dc0               jaccard
# 28                None                 None           monge_elkan
# 29                None                 None                   lev
# 30                None                 None      needleman_wunsch
# 31                None                 None        smith_waterman
# 32                None                 None  smith_waterman_gotoh
# 33                None                 None           exact_match
# 34                None                 None              abs_norm
# 35                None                 None                   lev
# 36               qgm_3                qgm_3               jaccard
# 37             dlm_dc0              dlm_dc0                cosine
# 38             dlm_dc0              dlm_dc0               jaccard
# 39                None                 None           monge_elkan
# 40                None                 None                   lev
# 41                None                 None      needleman_wunsch
# 42                None                 None        smith_waterman
# 43                None                 None  smith_waterman_gotoh
#
#                                              function  \
# 0              <function ID_ID_exm at 0x7feee96ab500>
# 1              <function ID_ID_anm at 0x7feee96ab230>
# 2              <function ID_ID_lev at 0x7feee96ab848>
# 3   <function name_name_jac_qgm_3_qgm_3 at 0x7feee...
# 4   <function name_name_cos_dlm_dc0_dlm_dc0 at 0x7...
# 5   <function name_name_jac_dlm_dc0_dlm_dc0 at 0x7...
# 6          <function name_name_mel at 0x7feee96aba28>
# 7          <function name_name_lev at 0x7feee96abaa0>
# 8          <function name_name_nmw at 0x7feee96abb18>
# 9           <function name_name_sw at 0x7feee96abb90>
# 10         <function name_name_swg at 0x7feee96abc08>
# 11       <function votes_votes_exm at 0x7feee96abc80>
# 12       <function votes_votes_anm at 0x7feee96abcf8>
# 13       <function votes_votes_lev at 0x7feee96abd70>
# 14     <function rating_rating_exm at 0x7feee96abde8>
# 15     <function rating_rating_anm at 0x7feee96abe60>
# 16     <function rating_rating_lev at 0x7feee96abed8>
# 17  <function phone_phone_jac_qgm_3_qgm_3 at 0x7fe...
# 18  <function phone_phone_cos_dlm_dc0_dlm_dc0 at 0...
# 19  <function phone_phone_jac_dlm_dc0_dlm_dc0 at 0...
# 20       <function phone_phone_mel at 0x7feee913f050>
# 21       <function phone_phone_lev at 0x7feee913f0c8>
# 22       <function phone_phone_nmw at 0x7feee913f140>
# 23        <function phone_phone_sw at 0x7feee913f1b8>
# 24       <function phone_phone_swg at 0x7feee913f230>
# 25  <function address_address_jac_qgm_3_qgm_3 at 0...
# 26  <function address_address_cos_dlm_dc0_dlm_dc0 ...
# 27  <function address_address_jac_dlm_dc0_dlm_dc0 ...
# 28   <function address_address_mel at 0x7feee913f410>
# 29   <function address_address_lev at 0x7feee913f488>
# 30   <function address_address_nmw at 0x7feee913f500>
# 31    <function address_address_sw at 0x7feee913f578>
# 32   <function address_address_swg at 0x7feee913f5f0>
# 33           <function zip_zip_exm at 0x7feee913f668>
# 34           <function zip_zip_anm at 0x7feee913f6e0>
# 35           <function zip_zip_lev at 0x7feee913f758>
# 36  <function cuisine_cuisine_jac_qgm_3_qgm_3 at 0...
# 37  <function cuisine_cuisine_cos_dlm_dc0_dlm_dc0 ...
# 38  <function cuisine_cuisine_jac_dlm_dc0_dlm_dc0 ...
# 39   <function cuisine_cuisine_mel at 0x7feee913f938>
# 40   <function cuisine_cuisine_lev at 0x7feee913f9b0>
# 41   <function cuisine_cuisine_nmw at 0x7feee913fa28>
# 42    <function cuisine_cuisine_sw at 0x7feee913faa0>
# 43   <function cuisine_cuisine_swg at 0x7feee913fb18>
#
#                                       function_source
# 0   from magellan.feature.simfunctions import *\nf...
# 1   from magellan.feature.simfunctions import *\nf...
# 2   from magellan.feature.simfunctions import *\nf...
# 3   from magellan.feature.simfunctions import *\nf...
# 4   from magellan.feature.simfunctions import *\nf...
# 5   from magellan.feature.simfunctions import *\nf...
# 6   from magellan.feature.simfunctions import *\nf...
# 7   from magellan.feature.simfunctions import *\nf...
# 8   from magellan.feature.simfunctions import *\nf...
# 9   from magellan.feature.simfunctions import *\nf...
# 10  from magellan.feature.simfunctions import *\nf...
# 11  from magellan.feature.simfunctions import *\nf...
# 12  from magellan.feature.simfunctions import *\nf...
# 13  from magellan.feature.simfunctions import *\nf...
# 14  from magellan.feature.simfunctions import *\nf...
# 15  from magellan.feature.simfunctions import *\nf...
# 16  from magellan.feature.simfunctions import *\nf...
# 17  from magellan.feature.simfunctions import *\nf...
# 18  from magellan.feature.simfunctions import *\nf...
# 19  from magellan.feature.simfunctions import *\nf...
# 20  from magellan.feature.simfunctions import *\nf...
# 21  from magellan.feature.simfunctions import *\nf...
# 22  from magellan.feature.simfunctions import *\nf...
# 23  from magellan.feature.simfunctions import *\nf...
# 24  from magellan.feature.simfunctions import *\nf...
# 25  from magellan.feature.simfunctions import *\nf...
# 26  from magellan.feature.simfunctions import *\nf...
# 27  from magellan.feature.simfunctions import *\nf...
# 28  from magellan.feature.simfunctions import *\nf...
# 29  from magellan.feature.simfunctions import *\nf...
# 30  from magellan.feature.simfunctions import *\nf...
# 31  from magellan.feature.simfunctions import *\nf...
# 32  from magellan.feature.simfunctions import *\nf...
# 33  from magellan.feature.simfunctions import *\nf...
# 34  from magellan.feature.simfunctions import *\nf...
# 35  from magellan.feature.simfunctions import *\nf...
# 36  from magellan.feature.simfunctions import *\nf...
# 37  from magellan.feature.simfunctions import *\nf...
# 38  from magellan.feature.simfunctions import *\nf...
# 39  from magellan.feature.simfunctions import *\nf...
# 40  from magellan.feature.simfunctions import *\nf...
# 41  from magellan.feature.simfunctions import *\nf...
# 42  from magellan.feature.simfunctions import *\nf...
# 43  from magellan.feature.simfunctions import *\nf...

# %%
# Add trigger: we have 0 FP and 2 FN, so we'll apply name matching rule
neg_trigger = mg.MatchTrigger()
neg_trigger.add_cond_rule('name_name_lev(ltuple, rtuple) < 0.1', feat_table)
neg_trigger.add_cond_status(True)
neg_trigger.add_action(0)
# Out:
# True

# %%
# Check whether the added trigger improves the accuracy in the test set.
# Steps
# 1. Train DT using U
# 2. Predict V using DT
# 3. Apply trigger
# 4. Evaluate the result

# %%
# Train dt using U
dt.fit(table=U, 
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'], 
       target_attr='gold')

# %%
# Predict V using dt
P = dt.predict(table=V, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'], 
              append=True, target_attr='predicted', inplace=False)

# %%
# Apply trigger
Q = neg_trigger.execute(P, 'predicted', inplace=False)

# %%
# Evaluate the result
eval_result = mg.eval_matches(Q, 'predicted', 'gold')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 97.22% (35/36)
# Recall : 100.0% (35/35)
# F1 : 98.59%
# False positives : 1 (out of 36 positive predictions)
# False negatives : 0 (out of 119 negative predictions)

# %%
UV = mg.train_test_split(K, train_proportion=0.5, random_state=0)
U = UV['train']
V = UV['test']
mg.vis_debug_dt(dt, U, V,
        exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
        target_attr='gold')

# %%
# Do cross-validation for matcher + trigger using I (K)
result = mg.cv_matcher_and_trigger(dt, neg_trigger, table = K, 
                                   exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
                                  target_attr='gold')
# Out:
# 0%  100%
# [#####] | ETA[sec]: 0.000
# Total time elapsed: 1.729 sec

# %%
result['cv_stats']
# Out:
#       Metric  Num folds  Fold 1  Fold 2    Fold 3    Fold 4  Fold 5  \
# 0  precision          5       1       1  0.941176  0.933333       1
# 1     recall          5       1       1  0.941176  0.933333       1
# 2         f1          5       1       1  0.941176  0.933333       1
#
#    Mean score
# 0    0.974902
# 1    0.974902
# 2    0.974902

# %%
# Recall the cv for just the matcher (without trigger) was
result = mg.cv_matcher_and_trigger(dt, [], table = K, 
                                   exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
                                  target_attr='gold')
# Out:
# 0%  100%
# [#####] | ETA[sec]: 0.000
# Total time elapsed: 0.869 sec

# %%
result['cv_stats']
# Out:
#       Metric  Num folds    Fold 1    Fold 2    Fold 3  Fold 4    Fold 5  \
# 0  precision          5  0.947368  1.000000  0.941176       1  0.909091
# 1     recall          5  1.000000  0.933333  1.000000       1  0.833333
# 2         f1          5  0.972973  0.965517  0.969697       1  0.869565
#
#    Mean score
# 0    0.959527
# 1    0.953333
# 2    0.955550

# %%
# Now Z is DT (features: feat_subset_iter2) + neg_trigger
# Validate Z using J
# Steps
# 1. Extract feature vectors (using feat_subset_iter2) -- > M
# 2. Train DT using H (feature vectors generated using I)
# 3. Predict M using DT
# 4. Apply negative trigger
# 5. Evaluate the result

# %%
# Extract feature vectors
M = mg.extract_feature_vecs(J, feature_table=feat_subset_iter2, attrs_after='gold')
# Impute missing values
M.fillna(0, inplace=True)

# %%
# Train using feature vectors from I 
dt.fit(table=K, 
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'], 
       target_attr='gold')

# %%
# Predict M 
N = dt.predict(table=M, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'], 
              append=True, target_attr='predicted', inplace=False)

# %%
# Apply trigger
T = neg_trigger.execute(N, 'predicted', inplace=False)

# %%
# Evaluate the result
eval_result = mg.eval_matches(T, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (16/16)
# Recall : 88.89% (16/18)
# F1 : 94.12%
# False positives : 0 (out of 16 positive predictions)
# False negatives : 2 (out of 118 negative predictions)

# %%
dt.fit(table=K,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
N = dt.predict(table=M, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(N, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (16/16)
# Recall : 88.89% (16/18)
# F1 : 94.12%
# False positives : 0 (out of 16 positive predictions)
# False negatives : 2 (out of 118 negative predictions)

# %%
rf.fit(table=K,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
N = rf.predict(table=M, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(N, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (16/16)
# Recall : 88.89% (16/18)
# F1 : 94.12%
# False positives : 0 (out of 16 positive predictions)
# False negatives : 2 (out of 118 negative predictions)

# %%
svm.fit(table=K,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
N = svm.predict(table=M, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(N, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (16/16)
# Recall : 88.89% (16/18)
# F1 : 94.12%
# False positives : 0 (out of 16 positive predictions)
# False negatives : 2 (out of 118 negative predictions)

# %%
nb.fit(table=K,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
N = nb.predict(table=M, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(N, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 94.12% (16/17)
# Recall : 88.89% (16/18)
# F1 : 91.43%
# False positives : 1 (out of 17 positive predictions)
# False negatives : 2 (out of 117 negative predictions)

# %%
lg.fit(table=K,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
N = lg.predict(table=M, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(N, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (16/16)
# Recall : 88.89% (16/18)
# F1 : 94.12%
# False positives : 0 (out of 16 positive predictions)
# False negatives : 2 (out of 118 negative predictions)

# %%
ln.fit(table=K,
       exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
       target_attr='gold')
N = ln.predict(table=M, exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = mg.eval_matches(N, 'gold', 'predicted')
mg.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (16/16)
# Recall : 88.89% (16/18)
# F1 : 94.12%
# False positives : 0 (out of 16 positive predictions)
# False negatives : 2 (out of 118 negative predictions)

# %%
UV = mg.train_test_split(M, train_proportion=0.5, random_state=0)
U = UV['train']
V = UV['test']
mg.vis_debug_dt(dt, U, V,
        exclude_attrs=['_id', 'ltable.id', 'rtable.id', 'gold'],
        target_attr='gold')

# %%
T.to_csv('stage3_final_matches.csv')
# Out:
# True
