# %%
#Read in Redlist

import pandas as pd
import py_entitymatching as em
import math
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style
import re
style.use('ggplot')

# Read in csv as dataframe
pd.read_csv('countryInfo.txt', sep='\t', lineterminator='\r')
# Out:
#      #ISO ISO3  ISO-Numeric fips                               Country  \
# 0    \nAD  AND           20   AN                               Andorra
# 1    \nAE  ARE          784   AE                  United Arab Emirates
# 2    \nAF  AFG            4   AF                           Afghanistan
# 3    \nAG  ATG           28   AC                   Antigua and Barbuda
# 4    \nAI  AIA          660   AV                              Anguilla
# 5    \nAL  ALB            8   AL                               Albania
# 6    \nAM  ARM           51   AM                               Armenia
# 7    \nAO  AGO           24   AO                                Angola
# 8    \nAQ  ATA           10   AY                            Antarctica
# 9    \nAR  ARG           32   AR                             Argentina
# 10   \nAS  ASM           16   AQ                        American Samoa
# 11   \nAT  AUT           40   AU                               Austria
# 12   \nAU  AUS           36   AS                             Australia
# 13   \nAW  ABW          533   AA                                 Aruba
# 14   \nAX  ALA          248  NaN                         Aland Islands
# 15   \nAZ  AZE           31   AJ                            Azerbaijan
# 16   \nBA  BIH           70   BK                Bosnia and Herzegovina
# 17   \nBB  BRB           52   BB                              Barbados
# 18   \nBD  BGD           50   BG                            Bangladesh
# 19   \nBE  BEL           56   BE                               Belgium
# 20   \nBF  BFA          854   UV                          Burkina Faso
# 21   \nBG  BGR          100   BU                              Bulgaria
# 22   \nBH  BHR           48   BA                               Bahrain
# 23   \nBI  BDI          108   BY                               Burundi
# 24   \nBJ  BEN          204   BN                                 Benin
# 25   \nBL  BLM          652   TB                      Saint Barthelemy
# 26   \nBM  BMU           60   BD                               Bermuda
# 27   \nBN  BRN           96   BX                                Brunei
# 28   \nBO  BOL           68   BL                               Bolivia
# 29   \nBQ  BES          535  NaN    Bonaire, Saint Eustatius and Saba
# ..    ...  ...          ...  ...                                   ...
# 222  \nTM  TKM          795   TX                          Turkmenistan
# 223  \nTN  TUN          788   TS                               Tunisia
# 224  \nTO  TON          776   TN                                 Tonga
# 225  \nTR  TUR          792   TU                                Turkey
# 226  \nTT  TTO          780   TD                   Trinidad and Tobago
# 227  \nTV  TUV          798   TV                                Tuvalu
# 228  \nTW  TWN          158   TW                                Taiwan
# 229  \nTZ  TZA          834   TZ                              Tanzania
# 230  \nUA  UKR          804   UP                               Ukraine
# 231  \nUG  UGA          800   UG                                Uganda
# 232  \nUM  UMI          581  NaN  United States Minor Outlying Islands
# 233  \nUS  USA          840   US                         United States
# 234  \nUY  URY          858   UY                               Uruguay
# 235  \nUZ  UZB          860   UZ                            Uzbekistan
# 236  \nVA  VAT          336   VT                               Vatican
# 237  \nVC  VCT          670   VC      Saint Vincent and the Grenadines
# 238  \nVE  VEN          862   VE                             Venezuela
# 239  \nVG  VGB           92   VI                British Virgin Islands
# 240  \nVI  VIR          850   VQ                   U.S. Virgin Islands
# 241  \nVN  VNM          704   VM                               Vietnam
# 242  \nVU  VUT          548   NH                               Vanuatu
# 243  \nWF  WLF          876   WF                     Wallis and Futuna
# 244  \nWS  WSM          882   WS                                 Samoa
# 245  \nYE  YEM          887   YM                                 Yemen
# 246  \nYT  MYT          175   MF                               Mayotte
# 247  \nZA  ZAF          710   SF                          South Africa
# 248  \nZM  ZMB          894   ZA                                Zambia
# 249  \nZW  ZWE          716   ZI                              Zimbabwe
# 250  \nCS  SCG          891   YI                 Serbia and Montenegro
# 251  \nAN  ANT          530   NT                  Netherlands Antilles
#
#                  Capital  Area(in sq km)  Population Continent  tld  \
# 0       Andorra la Vella          468.00       84000        EU  .ad
# 1              Abu Dhabi        82880.00     4975593        AS  .ae
# 2                  Kabul       647500.00    29121286        AS  .af
# 3             St. John's          443.00       86754       NaN  .ag
# 4             The Valley          102.00       13254       NaN  .ai
# 5                 Tirana        28748.00     2986952        EU  .al
# 6                Yerevan        29800.00     2968000        AS  .am
# 7                 Luanda      1246700.00    13068161        AF  .ao
# 8                    NaN     14000000.00           0        AN  .aq
# 9           Buenos Aires      2766890.00    41343201        SA  .ar
# 10             Pago Pago          199.00       57881        OC  .as
# 11                Vienna        83858.00     8205000        EU  .at
# 12              Canberra      7686850.00    21515754        OC  .au
# 13            Oranjestad          193.00       71566       NaN  .aw
# 14             Mariehamn             NaN       26711        EU  .ax
# 15                  Baku        86600.00     8303512        AS  .az
# 16              Sarajevo        51129.00     4590000        EU  .ba
# 17            Bridgetown          431.00      285653       NaN  .bb
# 18                 Dhaka       144000.00   156118464        AS  .bd
# 19              Brussels        30510.00    10403000        EU  .be
# 20           Ouagadougou       274200.00    16241811        AF  .bf
# 21                 Sofia       110910.00     7148785        EU  .bg
# 22                Manama          665.00      738004        AS  .bh
# 23             Bujumbura        27830.00     9863117        AF  .bi
# 24            Porto-Novo       112620.00     9056010        AF  .bj
# 25              Gustavia           21.00        8450       NaN  .gp
# 26              Hamilton           53.00       65365       NaN  .bm
# 27   Bandar Seri Begawan         5770.00      395027        AS  .bn
# 28                 Sucre      1098580.00     9947418        SA  .bo
# 29                   NaN             NaN       18012       NaN  .bq
# ..                   ...             ...         ...       ...  ...
# 222             Ashgabat       488100.00     4940916        AS  .tm
# 223                Tunis       163610.00    10589025        AF  .tn
# 224           Nuku'alofa          748.00      122580        OC  .to
# 225               Ankara       780580.00    77804122        AS  .tr
# 226        Port of Spain         5128.00     1228691       NaN  .tt
# 227             Funafuti           26.00       10472        OC  .tv
# 228               Taipei        35980.00    22894384        AS  .tw
# 229               Dodoma       945087.00    41892895        AF  .tz
# 230                 Kiev       603700.00    45415596        EU  .ua
# 231              Kampala       236040.00    33398682        AF  .ug
# 232                  NaN            0.00           0        OC  .um
# 233           Washington      9629091.00   310232863       NaN  .us
# 234           Montevideo       176220.00     3477000        SA  .uy
# 235             Tashkent       447400.00    27865738        AS  .uz
# 236         Vatican City            0.44         921        EU  .va
# 237            Kingstown          389.00      104217       NaN  .vc
# 238              Caracas       912050.00    27223228        SA  .ve
# 239            Road Town          153.00       21730       NaN  .vg
# 240     Charlotte Amalie          352.00      108708       NaN  .vi
# 241                Hanoi       329560.00    89571130        AS  .vn
# 242            Port Vila        12200.00      221552        OC  .vu
# 243             Mata Utu          274.00       16025        OC  .wf
# 244                 Apia         2944.00      192001        OC  .ws
# 245                Sanaa       527970.00    23495361        AS  .ye
# 246            Mamoudzou          374.00      159042        AF  .yt
# 247             Pretoria      1219912.00    49000000        AF  .za
# 248               Lusaka       752614.00    13460305        AF  .zm
# 249               Harare       390580.00    11651858        AF  .zw
# 250             Belgrade       102350.00    10829175        EU  .cs
# 251           Willemstad          960.00      136197       NaN  .an
#
#     CurrencyCode CurrencyName    Phone Postal Code Format  \
# 0            EUR         Euro      376              AD###
# 1            AED       Dirham      971                NaN
# 2            AFN      Afghani       93                NaN
# 3            XCD       Dollar   +1-268                NaN
# 4            XCD       Dollar   +1-264                NaN
# 5            ALL          Lek      355                NaN
# 6            AMD         Dram      374             ######
# 7            AOA       Kwanza      244                NaN
# 8            NaN          NaN      NaN                NaN
# 9            ARS         Peso       54           @####@@@
# 10           USD       Dollar   +1-684                NaN
# 11           EUR         Euro       43               ####
# 12           AUD       Dollar       61               ####
# 13           AWG      Guilder      297                NaN
# 14           EUR         Euro  +358-18              #####
# 15           AZN        Manat      994            AZ ####
# 16           BAM        Marka      387              #####
# 17           BBD       Dollar   +1-246            BB#####
# 18           BDT         Taka      880               ####
# 19           EUR         Euro       32               ####
# 20           XOF        Franc      226                NaN
# 21           BGN          Lev      359               ####
# 22           BHD        Dinar      973           ####|###
# 23           BIF        Franc      257                NaN
# 24           XOF        Franc      229                NaN
# 25           EUR         Euro      590            ### ###
# 26           BMD       Dollar   +1-441              @@ ##
# 27           BND       Dollar      673             @@####
# 28           BOB    Boliviano      591                NaN
# 29           USD       Dollar      599                NaN
# ..           ...          ...      ...                ...
# 222          TMT        Manat      993             ######
# 223          TND        Dinar      216               ####
# 224          TOP      Pa'anga      676                NaN
# 225          TRY         Lira       90              #####
# 226          TTD       Dollar   +1-868                NaN
# 227          AUD       Dollar      688                NaN
# 228          TWD       Dollar      886              #####
# 229          TZS     Shilling      255                NaN
# 230          UAH      Hryvnia      380              #####
# 231          UGX     Shilling      256                NaN
# 232          USD      Dollar         1                NaN
# 233          USD       Dollar        1         #####-####
# 234          UYU         Peso      598              #####
# 235          UZS          Som      998             ######
# 236          EUR         Euro      379              #####
# 237          XCD       Dollar   +1-784                NaN
# 238          VEF      Bolivar       58               ####
# 239          USD       Dollar   +1-284                NaN
# 240          USD       Dollar   +1-340         #####-####
# 241          VND         Dong       84             ######
# 242          VUV         Vatu      678                NaN
# 243          XPF        Franc      681              #####
# 244          WST         Tala      685                NaN
# 245          YER         Rial      967                NaN
# 246          EUR         Euro      262              #####
# 247          ZAR         Rand       27               ####
# 248          ZMW       Kwacha      260              #####
# 249          ZWL       Dollar      263                NaN
# 250          RSD        Dinar      381              #####
# 251          ANG      Guilder      599                NaN
#
#           Postal Code Regex                             Languages  geonameid  \
# 0          ^(?:AD)*(\d{3})$                                    ca  3041565.0
# 1                       NaN                     ar-AE,fa,en,hi,ur   290557.0
# 2                       NaN                     fa-AF,ps,uz-AF,tk  1149361.0
# 3                       NaN                                 en-AG  3576396.0
# 4                       NaN                                 en-AI  3573511.0
# 5                       NaN                                 sq,el   783754.0
# 6                 ^(\d{6})$                                    hy   174982.0
# 7                       NaN                                 pt-AO  3351879.0
# 8                       NaN                                   NaN  6697173.0
# 9    ^([A-Z]\d{4}[A-Z]{3})$                  es-AR,en,it,de,fr,gn  3865483.0
# 10                      NaN                           en-AS,sm,to  5880801.0
# 11                ^(\d{4})$                        de-AT,hr,hu,sl  2782113.0
# 12                ^(\d{4})$                                 en-AU  2077456.0
# 13                      NaN                           nl-AW,es,en  3577279.0
# 14         ^(?:FI)*(\d{5})$                                 sv-AX   661882.0
# 15         ^(?:AZ)*(\d{4})$                              az,ru,hy   587116.0
# 16                ^(\d{5})$                        bs,hr-BA,sr-BA  3277605.0
# 17         ^(?:BB)*(\d{5})$                                 en-BB  3374084.0
# 18                ^(\d{4})$                              bn-BD,en  1210997.0
# 19                ^(\d{4})$                     nl-BE,fr-BE,de-BE  2802361.0
# 20                      NaN                                 fr-BF  2361809.0
# 21                ^(\d{4})$                              bg,tr-BG   732800.0
# 22             ^(\d{3}\d?)$                        ar-BH,en,fa,ur   290291.0
# 23                      NaN                              fr-BI,rn   433561.0
# 24                      NaN                                 fr-BJ  2395170.0
# 25                      NaN                                    fr  3578476.0
# 26        ^([A-Z]{2}\d{2})$                              en-BM,pt  3573345.0
# 27        ^([A-Z]{2}\d{4})$                           ms-BN,en-BN  1820814.0
# 28                      NaN                           es-BO,qu,ay  3923057.0
# 29                      NaN                             nl,pap,en  7626844.0
# ..                      ...                                   ...        ...
# 222               ^(\d{6})$                              tk,ru,uz  1218197.0
# 223               ^(\d{4})$                              ar-TN,fr  2464461.0
# 224                     NaN                              to,en-TO  4032283.0
# 225               ^(\d{5})$                    tr-TR,ku,diq,az,av   298795.0
# 226                     NaN                    en-TT,hns,fr,es,zh  3573591.0
# 227                     NaN                         tvl,en,sm,gil  2110297.0
# 228               ^(\d{5})$                      zh-TW,zh,nan,hak  1668284.0
# 229                     NaN                           sw-TZ,en,ar   149590.0
# 230               ^(\d{5})$                    uk,ru-UA,rom,pl,hu   690791.0
# 231                     NaN                        en-UG,lg,sw,ar   226074.0
# 232                     NaN                                 en-UM  5854968.0
# 233        ^\d{5}(-\d{4})?$                    en-US,es-US,haw,fr  6252001.0
# 234               ^(\d{5})$                                 es-UY  3439705.0
# 235               ^(\d{6})$                              uz,ru,tg  1512440.0
# 236               ^(\d{5})$                              la,it,fr  3164670.0
# 237                     NaN                              en-VC,fr  3577815.0
# 238               ^(\d{4})$                                 es-VE  3625428.0
# 239                     NaN                                 en-VG  3577718.0
# 240        ^\d{5}(-\d{4})?$                                 en-VI  4796775.0
# 241               ^(\d{6})$                        vi,en,fr,zh,km  1562822.0
# 242                     NaN                        bi,en-VU,fr-VU  2134431.0
# 243            ^(986\d{2})$                         wls,fud,fr-WF  4034749.0
# 244                     NaN                              sm,en-WS  4034894.0
# 245                     NaN                                 ar-YE    69543.0
# 246               ^(\d{5})$                                 fr-YT  1024031.0
# 247               ^(\d{4})$  zu,xh,af,nso,en-ZA,tn,st,ts,ss,ve,nr   953987.0
# 248               ^(\d{5})$          en-ZM,bem,loz,lun,lue,ny,toi   895949.0
# 249                     NaN                        en-ZW,sn,nr,nd   878675.0
# 250               ^(\d{5})$                           cu,hu,sq,sr        NaN
# 251                     NaN                           nl-AN,en,es        NaN
#
#                   neighbours EquivalentFipsCode
# 0                      ES,FR                NaN
# 1                      SA,OM                NaN
# 2          TM,CN,IR,TJ,PK,UZ                NaN
# 3                        NaN                NaN
# 4                        NaN                NaN
# 5             MK,GR,ME,RS,XK                NaN
# 6                GE,IR,AZ,TR                NaN
# 7                CD,NA,ZM,CG                NaN
# 8                        NaN                NaN
# 9             CL,BO,UY,PY,BR                NaN
# 10                       NaN                NaN
# 11   CH,DE,HU,SK,CZ,IT,SI,LI                NaN
# 12                       NaN                NaN
# 13                       NaN                NaN
# 14                       NaN                 FI
# 15            GE,IR,AM,TR,RU                NaN
# 16                  HR,ME,RS                NaN
# 17                       NaN                NaN
# 18                     MM,IN                NaN
# 19               DE,NL,LU,FR                NaN
# 20         NE,BJ,GH,CI,TG,ML                NaN
# 21            MK,GR,RO,TR,RS                NaN
# 22                       NaN                NaN
# 23                  TZ,CD,RW                NaN
# 24               NE,TG,BF,NG                NaN
# 25                       NaN                NaN
# 26                       NaN                NaN
# 27                        MY                NaN
# 28            PE,CL,PY,BR,AR                NaN
# 29                       NaN                NaN
# ..                       ...                ...
# 222              AF,IR,UZ,KZ                NaN
# 223                    DZ,LY                NaN
# 224                      NaN                NaN
# 225  SY,GE,IQ,IR,GR,AM,AZ,BG                NaN
# 226                      NaN                NaN
# 227                      NaN                NaN
# 228                      NaN                NaN
# 229  MZ,KE,CD,RW,ZM,BI,UG,MW                NaN
# 230     PL,MD,HU,SK,BY,RO,RU                NaN
# 231           TZ,KE,SS,CD,RW                NaN
# 232                      NaN                NaN
# 233                 CA,MX,CU                NaN
# 234                    BR,AR                NaN
# 235           TM,AF,KG,TJ,KZ                NaN
# 236                       IT                NaN
# 237                      NaN                NaN
# 238                 GY,BR,CO                NaN
# 239                      NaN                NaN
# 240                      NaN                NaN
# 241                 CN,LA,KH                NaN
# 242                      NaN                NaN
# 243                      NaN                NaN
# 244                      NaN                NaN
# 245                    SA,OM                NaN
# 246                      NaN                NaN
# 247        ZW,SZ,MZ,BW,NA,LS                NaN
# 248     ZW,TZ,MZ,CD,NA,MW,AO                NaN
# 249              ZA,MZ,BW,ZM                NaN
# 250     AL,HU,MK,RO,HR,BA,BG                NaN
# 251                       GP                NaN
#
# [252 rows x 19 columns]

# %%
# CME
rl.columns# get key

# Note: The id column of the  redlist csv doesn't actually look like the object created here (rl).  In the csv,
# id numbers jump around since they represent original row number of the original scraped data csv.  Apparently
# this library can detect what we want and enumerate things in order if you give it a key feature like this.

# %%
#Read in ARKIVE
# Read in csv as dataframe
ar = em.read_csv_metadata("finalArkives.csv", encoding="ISO-8859-1", key="id")

# glance at first few rows
ar.head()

# %%
# Remove parentheticals from arkive common names
# author: CME
# Next, actually remove scientific name and replace with common name(s)
#ar = arBeforeRemovingNames # in case script now run completely in order
#ar = ar[ar.animalName.str.contains("\(") == True] # update df to contain only tuples that contain common/nick names
error = 0 # make sure there's no wonky cases

# remove parenthesis contents
for index, row in ar.iterrows():
    genus = str(row['name'])

    pstart = genus.find("(")
    if pstart !=-1:        
        # extract full common/nick name
        noparens = genus[0:pstart]
        ar.loc[index, 'name'] = noparens
    else:
        error = error + 1

print(error)

# %%
# Concatenate nickname and common_name fields in arkive
# author: @andrewedstrom

# remove parenthesis contents
nameColumn = []
for index, row in ar.iterrows():
    nickname = str(row['scientific_name']) #look here if errors start happening
    nickname = re.sub('[^A-Za-z0-9;,\s]+', '', nickname).lower()
    common = str(row['common_name'])
    common = re.sub('[^A-Za-z0-9;,\s]+', '', common).lower()
    if common in nickname: 
        nameColumn.append(nickname)
    else:
        nameColumn.append((nickname + "; " + common))
ar['name'] = nameColumn
ar.head()

# %%
# Lowercase redlist name field
# author: @andrewedstrom
error = 0 # make sure there's no wonky cases

# remove parenthesis contents
for index, row in rl.iterrows():
    n = str(row['name'])
    n = re.sub('[^A-Za-z0-9;,\s]+', '', n).lower()

    rl.loc[index, 'name'] = n.lower()

rl.head()
# Out:
#    id                        name         genus          family      ecology  \
# 0   0   ochlockonee moccasinshell    Medionidus       Unionidae   Freshwater
# 1   1  nelsons spiny pocket mouse     Heteromys    Heteromyidae  Terrestrial
# 2   2                comoro friar       Amauris     Nymphalidae          NaN
# 3   3   atlantic halibut, halibut  Hippoglossus  Pleuronectidae          NaN
# 4   4                         nan       Hirasea    Endodontidae          NaN
#
#                                                                                              countries  \
# 0                                                                   United States (Florida, Georgia);
# 1                                                                        Guatemala; Mexico (Chiapas);
# 2                                                                                            Comoros;
# 3  <div>Atlantic â northeast; Atlantic â northwest</div>; Canada (Newfoundland I); Denmark; Far...
# 4                                                                            Japan (Ogasawara-shoto);
#
#                                                                                       threat_paragraph  \
# 0                                                                                                  NaN
# 1  \r\n    The main threat to this species is the significant forest loss in its habitat. Habitat f...
# 2                                                                                                  NaN
# 3                                                                                                  NaN
# 4                                                                                                  NaN
#
#                                                                          conservation_paragraph  \
# 0                                                                                           NaN
# 1  ['\n    This species occurs in a newly-named national park, Tacana, in Mexico.\n\n    \n  ']
# 2                                                                                           NaN
# 3                                                                                           NaN
# 4                                                                                           NaN
#
#     pop_trend                                                          status  \
# 0         NaN   \r\n    Critically Endangered\r\n\r\n\r\n    A1ce\r\n\r\n
# 1  Decreasing  \r\n    Endangered\r\n\r\n\r\n    B1ab(i,ii,iii,v)\r\n\r\n
# 2         NaN        \r\n    Endangered\r\n\r\n\r\n    B1+2c, C2b\r\n\r\n
# 3         NaN               \r\n    Endangered\r\n\r\n\r\n    A1d\r\n\r\n
# 4         NaN               \r\n    Endangered\r\n\r\n\r\n    A1d\r\n\r\n
#
#    country_count            scientific_name
# 0              1    Medionidus simpsonianus
# 1              2          Heteromys nelsoni
# 2              1           Amauris comorana
# 3             15  Hippoglossus hippoglossus
# 4              1         Hirasea acutissima

# %%
# Remove parentheticals from arkive genus
# author: @andrewedstrom
# Next, actually remove scientific name and replace with common name(s)
#ar = arBeforeRemovingNames # in case script now run completely in order
#ar = ar[ar.animalName.str.contains("\(") == True] # update df to contain only tuples that contain common/nick names
error = 0 # make sure there's no wonky cases

# remove parenthesis contents
for index, row in ar.iterrows():
    genus = str(row['genus'])

    pstart = genus.find("(")
    if pstart !=-1:        
        # extract full common/nick name
        noparens = genus[0:pstart]
        ar.loc[index, 'genus'] = noparens
    else:
        error = error + 1

print(error)

# %%
rl.to_csv('finalRedlist.csv')
#ar.to_csv('finalArkives.csv')

# %%
# Rule-based blocking over input tables
# first get features that can be used
feature_table = em.get_features_for_blocking(rl, ar)

# %%
#len(feature_table)
feature_table
#em.get_attr_corres(rl, ar)['ltable']

# %%
# CME -- I'm realizing now that we may want to start with the attribute equivalence
# blocker for names and see where that leaves us.  On my TO-DO.
equivB = em.AttrEquivalenceBlocker()
C0 = equivB.block_tables(rl, ar, 'name', 'name',
                    l_output_attrs=['name', 'genus'], 
                    r_output_attrs=['name', 'genus'])
C0

# lolwat this reveals zero matches?

# %%
#Do overlap blocking on name to get candidate set
#Perform some kind of blocking to find candidate pairs
ob = em.OverlapBlocker()
C0 = ob.block_tables(rl, ar,'name', 'name', 
                     l_output_attrs=['name', 'genus', 'family'], 
                     r_output_attrs=['name', 'genus', 'family'], overlap_size=2)
C0

# %%
#Only keep candidate pairs which share genus
ab = em.AttrEquivalenceBlocker()
C1 = ob.block_candset(C0, 'genus', 'genus')
C1

#Do overlap blocking on name to get candidate set
#Perform some kind of blocking to find candidate pairs
#C1 = ab.block_tables(rl, ar,'genus', 'genus', 
#                     l_output_attrs=['name', 'genus'], 
#                     r_output_attrs=['name', 'genus'])

# %%
C2 = equivB.block_tables(rl, ar, 'family', 'family',
                    l_output_attrs=['name', 'genus' ,'family'], 
                    r_output_attrs=['name', 'genus', 'family'])

C3 = ob.block_candset(C2, 'genus', 'genus')
C3

# %%
C = em.combine_blocker_outputs_via_union([C1, C3])
C

# %%
em.to_csv_metadata(C, './candidate_set.csv')

# %%
C = em.read_csv_metadata('candidate_set.csv', ltable=rl, rtable=ar)

# %%
C
